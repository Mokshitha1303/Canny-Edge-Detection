# %% [markdown]
# <a href="https://colab.research.google.com/github/Mokshitha1303/Canny-Edge-Detection/blob/main/Canny_Edge_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow
img = cv2.imread('/content/images.jpeg', cv2.IMREAD_UNCHANGED)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168>

# %%
# Convert to graycsale
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
# Blur the image for better edge detection
img_blur = cv2.GaussianBlur(img_gray, (3,3), 0)

# %%
# Sobel Edge Detection
sobelx = cv2.Sobel(src=img_blur, ddepth=cv2.CV_64F, dx=1, dy=0, ksize=5) # Sobel Edge Detection on the X axis
sobely = cv2.Sobel(src=img_blur, ddepth=cv2.CV_64F, dx=0, dy=1, ksize=5) # Sobel Edge Detection on the Y axis
sobelxy = cv2.Sobel(src=img_blur, ddepth=cv2.CV_64F, dx=1, dy=1, ksize=5) # Combined X and Y Sobel Edge Detection

# %%
# Display Sobel Edge Detection Images
cv2_imshow(sobelx)
# Out:
# <PIL.Image.Image image mode=L size=300x168>

# %%
cv2_imshow(sobely)
# Out:
# <PIL.Image.Image image mode=L size=300x168>

# %%
cv2_imshow(sobely)
# Out:
# <PIL.Image.Image image mode=L size=300x168>

# %%
cv2_imshow(sobely)
# Out:
# <PIL.Image.Image image mode=L size=300x168>

# %%
cv2_imshow(sobelxy)
# Out:
# <PIL.Image.Image image mode=L size=300x168>

# %%
# Canny Edge Detection
edges = cv2.Canny(image=img_blur, threshold1=100, threshold2=200) # Canny Edge Detection

# %%
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=L size=300x168>
